# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
def bar_graph(filename):
    df=pd.read_csv(filename,usecols=range(1,11))
    df=df.dropna()
    plt.rcParams["figure.figsize"] = [14.50, 7.50]
    plt.rcParams["figure.autolayout"] = True
    df.plot.bar(width=0.8)
    plt.show()
    
def line_graph(filename, title):
    df=pd.read_csv(filename)
    df=df.dropna()
    plt.rcParams["figure.figsize"] = [9.50, 6.50]
    plt.rcParams["figure.autolayout"] = True
    df.set_index('YEAR').plot()
    plt.title(title)
    plt.show()

# %%
line_graph("./not_having_access/electricity.csv", "% of people not having access to electricity")

# %%
#Electricity data bar graph
df=pd.read_csv("./not_having_access/electricity.csv")
bar_graph("./not_having_access/electricity.csv")

# %%
def corelation2(filename):
    df1=pd.read_csv(filename)
    df2=pd.read_csv("./having_access/underonenine.csv")
    
    df1_india=df1['India ']
    df2_india=df2['India']
    df1_india.dropna()
    df2_india.dropna()
#     sum of values
    sum_india_df1=df1_india.sum()
    sum_india_df2=df2_india.sum()
# mean of all values
    mean_india_df1=df1_india.mean()
    mean_india_df2=df2_india.mean()
#     multiply two rows
    df12_multiply=df1_india*df2_india
    df12_sum=df12_multiply.sum()
# square of variable data
    df1_square=df1_india.pow(2)
    df2_square=df2_india.pow(2)
#     return df1_square
#     sum of values
    df1_square_sum=df1_square.sum()
    df2_square_sum=df2_square.sum()

# %%
def corelation(filename):
    df1=pd.read_csv(filename)
    df2=pd.read_csv("./having_access/underonenine.csv")
    
    df1_india=df1['India']
    df2_india=df2['India']
     
    corr=df2_india.corr(df1_india)
    nrows=len(df1.index)
    print(nrows)
    t=(corr(nrows-2))/(sqrt(1-(corr**2)))
    return print(t)
    
# n=number of rows
# r=corr
# def findt(corr,nrows):
#     nrows=

# %%
toilet_corr=corelation("./not_having_access/toilet.csv")
# electricity_corr=corelation("./not_having_access/electricity.csv")
# water_corr=corelation("./not_having_access/water.csv")
# cooking_fuel_corr=corelation("./not_having_access/cooking_fuel.csv")
# Out:
# 10
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-11-837a57a17e93> in <module>
# ----> 1 toilet_corr=corelation("./not_having_access/toilet.csv")
#       2 # electricity_corr=corelation("./not_having_access/electricity.csv")
#       3 # water_corr=corelation("./not_having_access/water.csv")
#       4 # cooking_fuel_corr=corelation("./not_having_access/cooking_fuel.csv")
#
# <ipython-input-10-f7f9c8d24925> in corelation(filename)
#       9     nrows=len(df1.index)
#      10     print(nrows)
# ---> 11     t=(corr(nrows-2))/(sqrt(1-(corr**2)))
#      12     return print(t)
#      13
#
# TypeError: 'int' object is not callable

# %%
# n=number of rows
# r=corr
# t=(r(n-2))/sqrt(1-(r**2))
findt(toilet_corr, len()
