# %% [markdown]
# # sourse

# %%
import pandas as pd
data3=pd.read_csv('ps3.csv')

# %%
data3
# Out:
#           COUNTRY    wind    hydro  solar  other
# 0          Brazil   21.63   365.15   0.06  49.45
# 1           Chile    2.11    23.41   1.24   5.62
# 2           China  185.62  1112.72  39.54  54.23
# 3         Germany   80.64    19.56  38.76  50.51
# 4           India   32.74   132.26   6.57  17.02
# 5           Japan    5.58    86.75  34.80  56.28
# 6          Mexico    8.45    30.61   0.24   7.36
# 7    South Africa    2.54     0.87   2.14   0.37
# 8  United Kingdom   40.27     6.37   7.53  28.47
# 9   United States  190.72   243.99  39.03  79.55

# %%
data3.plot.bar(x='COUNTRY',y=['solar','wind'],figsize=(20,10))
# Out:
# <AxesSubplot:xlabel='COUNTRY'>

# %%
data3.plot.bar(x='COUNTRY',y=['solar','other'],figsize=(20,10))
# Out:
# <AxesSubplot:xlabel='COUNTRY'>

# %%
data3.plot.bar(x='COUNTRY',y=['solar','hydro'],figsize=(20,10))
# Out:
# <AxesSubplot:xlabel='COUNTRY'>

# %%
data3.plot.bar(x='COUNTRY',y=['hydro','wind'],figsize=(20,10))
# Out:
# <AxesSubplot:xlabel='COUNTRY'>

# %%
data3.plot.bar(x='COUNTRY',y=['hydro','other'],figsize=(20,10))
# Out:
# <AxesSubplot:xlabel='COUNTRY'>

# %%
data3.plot.bar(x='COUNTRY',y=['wind','other'],figsize=(20,10))
# Out:
# <AxesSubplot:xlabel='COUNTRY'>

# %%
data3.plot.bar(figsize=(15,10))
# Out:
# <AxesSubplot:>

# %%
data3.groupby(['COUNTRY']).sum().plot(kind='pie',y='wind',figsize=(15,15))
# Out:
# <AxesSubplot:ylabel='wind'>

# %%
data3.groupby(['COUNTRY']).sum().plot(kind='pie',y='wind',figsize=(15,15))
# Out:
# <AxesSubplot:ylabel='wind'>

# %%
data3.groupby(['COUNTRY']).sum().plot(kind='pie',y='hydro',figsize=(15,15))
# Out:
# <AxesSubplot:ylabel='hydro'>

# %%
data3.groupby(['COUNTRY']).sum().plot(kind='pie',y='solar',figsize=(15,15))
# Out:
# <AxesSubplot:ylabel='solar'>

# %%
data3.groupby(['COUNTRY']).sum().plot(kind='pie',y='other',figsize=(15,15))
# Out:
# <AxesSubplot:ylabel='other'>

# %%
data3.plot.bar(x='COUNTRY',y=['wind','hydro','solar','other'],figsize=(20,10))
# Out:
# <AxesSubplot:xlabel='COUNTRY'>
